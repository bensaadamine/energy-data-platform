# %%
# %pip install requests
# Out:
# ...
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# ...
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# ...
#    ---------------------------------------- 0.0/153.7 kB ? eta -:--:--
#    ------------------ --------------------- 71.7/153.7 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  153.6/153.7 kB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 153.7/153.7 kB 1.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/142.4 kB ? eta -:--:--
#    ------------------------------------- -- 133.1/142.4 kB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 142.4/142.4 kB 2.1 MB/s eta 0:00:00
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# ...
#    ---------------------------------------- 0.0/131.6 kB ? eta -:--:--
#    ------------------------------------- -- 122.9/131.6 kB ? eta -:--:--
# ...

# %%
import requests
import json

API_KEY = "vdT5GoKJWL8qTTL0HKA6Ax1SaeSvJXKwR6Wfpz92"

url = "https://api.api-ninjas.com/v1/commodityprice?name=natural_gas"

headers = {
    "X-Api-Key": API_KEY
}

response = requests.get(url, headers=headers)

if response.status_code == 200:
    data = response.json()
    print("Raw response:")
    print(json.dumps(data, indent=2))
else:
    print("Error:", response.status_code, response.text)
# Out:
# Raw response:
# {
#   "exchange": "NYMEX",
#   "name": "Natural Gas",
#   "price": 3.09,
#   "updated": 1772804230
# }

# %%
import requests

API_KEY = "MLOW4Urhlzz1CigAh1vFhCng3TbHGLlGQqLetKpo"

url = f"https://api.eia.gov/v2/petroleum/pri/spt/data/?api_key={API_KEY}"

response = requests.get(url)

data = response.json()

print(data["response"]["data"][:5])
# Out:
# [{'period': '1996-04-19', 'duoarea': 'Y05LA', 'area-name': 'LOS ANGELES', 'product': 'EPD2DC', 'product-name': 'Carb Diesel', 'process': 'PF4', 'process-name': 'Spot Price FOB', 'series': 'EER_EPD2DC_PF4_Y05LA_DPG', 'series-description': 'Los Angeles, CA Ultra-Low Sulfur CARB Diesel Spot Price (Dollars per Gallon)'}, {'period': '1996-04-26', 'duoarea': 'Y05LA', 'area-name': 'LOS ANGELES', 'product': 'EPD2DC', 'product-name': 'Carb Diesel', 'process': 'PF4', 'process-name': 'Spot Price FOB', 'series': 'EER_EPD2DC_PF4_Y05LA_DPG', 'series-description': 'Los Angeles, CA Ultra-Low Sulfur CARB Diesel Spot Price (Dollars per Gallon)'}, {'period': '1996-05-03', 'duoarea': 'Y05LA', 'area-name': 'LOS ANGELES', 'product': 'EPD2DC', 'product-name': 'Carb Diesel', 'process': 'PF4', 'process-name': 'Spot Price FOB', 'series': 'EER_EPD2DC_PF4_Y05LA_DPG', 'series-description': 'Los Angeles, CA Ultra-Low Sulfur CARB Diesel Spot Price (Dollars per Gallon)'}, {'period': '1996-05-10', 'duoarea': 'Y05LA'
# ...

# %%
url = "https://api.worldbank.org/v2/country/all/indicator/EG.USE.PCAP.KG.OE?format=json"

response = requests.get(url)

data = response.json()

print(data[1][:5])
# Out:
# [{'indicator': {'id': 'EG.USE.PCAP.KG.OE', 'value': 'Energy use (kg of oil equivalent per capita)'}, 'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'}, 'countryiso3code': 'AFE', 'date': '2025', 'value': None, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'EG.USE.PCAP.KG.OE', 'value': 'Energy use (kg of oil equivalent per capita)'}, 'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'}, 'countryiso3code': 'AFE', 'date': '2024', 'value': None, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'EG.USE.PCAP.KG.OE', 'value': 'Energy use (kg of oil equivalent per capita)'}, 'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'}, 'countryiso3code': 'AFE', 'date': '2023', 'value': None, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'EG.USE.PCAP.KG.OE', 'value': 'Energy use (kg of oil equivalent per capita)'}, 'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'}, 'countryiso3code': 'AFE', 'date
# ...

# %% [markdown]
# Batch data for energy consumption analytics.

# %%
API_KEY = "YOUR_NEWSAPI_KEY"

url = f"https://newsapi.org/v2/everything?q=oil&language=en&apiKey={API_KEY}"

response = requests.get(url)

articles = response.json()["articles"]

for article in articles[:5]:
    print(article["title"], "-", article["publishedAt"])

# %%
# %pip install feedparser
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/81.5 kB ? eta -:--:--
#    ----- ---------------------------------- 10.2/81.5 kB ? eta -:--:--
#    -------------------- ------------------- 41.0/81.5 kB 487.6 kB/s eta 0:00:01
#    ----------------------------------- ---- 71.7/81.5 kB 653.6 kB/s eta 0:00:01
#    ---------------------------------------- 81.5/81.5 kB 569.9 kB/s eta 0:00:00
# ...
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6104 sha256=f359f87ce88f4cc9491af252bf203d73d1d5f0eba9e807edd446200c4d559b6a
# ...

# %%
import feedparser

rss = "https://oilprice.com/rss/main"

feed = feedparser.parse(rss)

for entry in feed.entries[:5]:
    print(entry.title)
# Out:
# Oil Prices Surge Toward $90 as Middle East Tensions Escalate
# Europe-Bound LNG Cargoes Divert to Asia as War Upends Gas Market
# IMF: Oil Price Shock Tests Global Economic Resilience
# HSFO Prices Jump 40% as War Chokes Key Singapore Bunkering Hub
# Why Trump Wants Magnets More Than Gold
